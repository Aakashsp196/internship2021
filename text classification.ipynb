# %%
import json
import pandas as pd
import numpy as np
from pandas import DataFrame
import nltk
nltk.download('all')
nltk.download('wordnet')
nltk.download('average_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import Porterstemmer
from textblob import Textblob
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Aakash
# [nltk_data]    |     Sadaphule\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\Aakash
# [nltk_data]    |     Sadaphule\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Aakash
# [nltk_data]    |     Sadaphule\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\Users\Aakash
# [nltk_data]    |     Sadaphule\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to C:\Users\Aakash
# [nltk_data]    |     Sadaphule\AppData\Roaming\nltk_data...
# ...

# %%
with open ("C:/Users/Aakash Sadaphule/Desktop/Untitled Folder/archive/MMHS150K_GT.json") as f:
    data = json.load(f)

# %%
data=pd.DataFrame.from_dict(data)
data=data.T
data=data.reset_index()
data.rename(columns={"index":"user_id"},inplace=True)

# %%
print('No. of rows: {} and columns are: {}'.format(data.shape[0],data.shape[1]))
data.head()
# Out:
# No. of rows: 149823 and columns are: 6
#                user_id                                            img_url  \
# 0  1114679353714016256  http://pbs.twimg.com/tweet_video_thumb/D3gi9MH...
# 1  1063020048816660480  http://pbs.twimg.com/ext_tw_video_thumb/106301...
# 2  1108927368075374593     http://pbs.twimg.com/media/D2OzhzHUwAADQjd.jpg
# 3  1114558534635618305  http://pbs.twimg.com/ext_tw_video_thumb/111401...
# 4  1035252480215592966     http://pbs.twimg.com/media/Dl30pGIU8AAVGxO.jpg
#
#       labels                                          tweet_url  \
# 0  [4, 1, 3]  https://twitter.com/user/status/11146793537140...
# 1  [5, 5, 5]  https://twitter.com/user/status/10630200488166...
# 2  [0, 0, 0]  https://twitter.com/user/status/11089273680753...
# 3  [1, 0, 0]  https://twitter.com/user/status/11145585346356...
# 4  [1, 0, 1]  https://twitter.com/user/status/10352524802155...
#
#                                           tweet_text  \
# ...

# %% [markdown]
# # Data Prepropcessing

# %%
def tweet_preprocessing(TXT):
    TXT = TXT.astype(str)

    TXT[0] = TXT[0].apply(lambda A: A.lower())
    
    TXT[0] = TXT[0].apply(lambda A: word_tokenize(A))

    TXT = TXT.astype(str)
    
    TXT[0] = TXT[0].str.replace('[^\w\s]',' ')
    

    stop = stopwords.words('english')
    TXT[0] = TXT[0].apply(lambda A: " ".join(A for A in A.split() if A not in stop))


    TXT[0] = TXT[0].apply(lambda A: lemma_conversion(A))


    TOKEN_T = TXT[0].apply(lambda A: A.split())
    ps = PorterStemmer()
    TOKEN_T = TOKEN_T.apply(lambda A: [ps.stem(i) for i in A])

    for i in range(len(TOKEN_T)):
        TOKEN_T[i] = ' '.join(TOKEN_T[i])
    TXT[0] = TOKEN_T
    return TXT

def lemma_conversion(sentence):
    sent = TextBlob(sentence)
    TL = {"J": 'a', 
                "N": 'n', 
                "V": 'v', 
                "R": 'r'}
    W_T= [(w, TL.get(pos[0], 'n')) for w, pos in sent.tags]    
    LemA_list = [wd.lemmatize(tag) for wd, tag in W_T]
    return " ".join(LemA_list)

# %%
def create_vocab(tweet):
    vocab_d={}
    for i in TXT:
        for j in A.split ():
            if j not  in vocab_d.keys():
               vocab_d [j]=len(vocab_d)+1
    return vocab_d

# %% [markdown]
# # TF-IDF word vectorizer

# %%
tweet = pd.DataFrame(data,columns=['tweet_text'])
tweet.head()
# Out:
#                                           tweet_text
# 0       @FriskDontMiss Nigga https://t.co/cAsaLWEpue
# 1     My horses are retarded https://t.co/HYhqc6d5WN
# 2  “NIGGA ON MA MOMMA YOUNGBOY BE SPITTING REAL S...
# 3  RT xxSuGVNGxx: I ran into this HOLY NIGGA TODA...
# 4  “EVERYbody calling you Nigger now!” https://t....

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(data['tweet_text'], data['labels_str'],test_size=0.2,random_state=0)
X_train
vec = TfidfVectorizer(sublinear_tf = True, use_idf = True)
v_train = vec.fit_transform(X_train)
v_test = vec.transform(X_test)

# %%
len(X_train)
# Out:
# 119858

# %%
len(X_test)
# Out:
# 29965

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-b7a8c64777c1> in <module>
# ----> 1 model.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     158             check_consistent_length(X, y)
#     159         else:
# --> 160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
#     162                                        accept_large_sparse=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
